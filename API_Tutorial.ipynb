# %%
# Load the API
from inaSpeechSegmenter import Segmenter
from inaSpeechSegmenter.export_funcs import seg2csv, seg2textgrid

# %% [markdown]
# # retrieve wav files with corresponding speaker id

# %%
root_path='../wav/' #这里是按照vox1的目录结构写的，vox1解压后的文件夹的名字是wav
wav_files=[]
import os
speaker_id = [f for f in os.listdir(root_path)]
for speaker in speaker_id:
    for dirpath, dirnames, filenames in os.walk(os.path.join(root_path,speaker)):
        wav_files+=[(speaker,os.path.join(dirpath,file)) for file in filenames]

# %%
len(wav_files)
# Out:
# 4874

# %%
saved=[]
for file in wav_files:
    seg=Segmenter()
    id=file[0]
    seg_result=seg(file[1])
    saved+=[(id,each[0]) for each in seg_result]
# Out:
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# ...
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:88: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(emission.T, consecutive)
# /users/yiwei/env/lib/python3.6/site-packages/pyannote/algorithms/utils/viterbi.py:97: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   for e, c in six.moves.zip(constraint.T, consecutive)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-802b3aa05907> in <module>
#       1 saved=[]
#       2 for file in wav_files:
# ----> 3     seg=Segmenter()
#       4     id=file[0]
#       5     # segmentation=['1']+seg(file)
#
# ~/inaSpeechSegmenter/inaSpeechSegmenter/segmenter.py in __init__(self, vad_engine, detect_gender, ffmpeg, batch_size, energy_ratio)
#     216             self.vad = SpeechMusic(batch_size)
#     217         elif vad_engine == 'smn':
# --> 218             self.vad = SpeechMusicNoise(batch_size)
#     219
#     220         # load gender detection NN if required
#
# ~/inaSpeechSegmenter/inaSpeechSegmenter/segmenter.py in __init__(self, batch_size)
#     107         url = 'https://github.com/ina-foss/inaSpeechSegmenter/releases/download/models/'
#     108         model_path = get_file(self.model_fname, url + self.model_fname, cache_subdir='inaSpeechSegmenter')
# --> 109         self.nn = keras.models.load_model(model_path, compile=False)
#     110         self.batch_size = batch_size
#     111
#
# ~/env/lib/python3.6/site-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     199             (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
#     200           return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
# --> 201                                                   compile)
#     202
#     203         filepath = path_to_string(filepath)
#
# ~/env/lib/python3.6/site-packages/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     179     model_config = json_utils.decode(model_config)
#     180     model = model_config_lib.model_from_config(model_config,
# --> 181                                                custom_objects=custom_objects)
#     182
#     183     # set weights
#
# ~/env/lib/python3.6/site-packages/keras/saving/model_config.py in model_from_config(config, custom_objects)
#      50                     '`Sequential.from_config(config)`?')
#      51   from keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 52   return deserialize(config, custom_objects=custom_objects)
#      53
#      54
#
# ~/env/lib/python3.6/site-packages/keras/layers/serialization.py in deserialize(config, custom_objects)
#     210       module_objects=LOCAL.ALL_OBJECTS,
#     211       custom_objects=custom_objects,
# --> 212       printable_module_name='layer')
#
# ~/env/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     676             custom_objects=dict(
#     677                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 678                 list(custom_objects.items())))
#     679       else:
#     680         with CustomObjectScope(custom_objects):
#
# ~/env/lib/python3.6/site-packages/keras/engine/sequential.py in from_config(cls, config, custom_objects)
#     431     for layer_config in layer_configs:
#     432       layer = layer_module.deserialize(layer_config,
# --> 433                                        custom_objects=custom_objects)
#     434       model.add(layer)
#     435     if (not model.inputs and build_input_shape and
#
# ~/env/lib/python3.6/site-packages/keras/layers/serialization.py in deserialize(config, custom_objects)
#     210       module_objects=LOCAL.ALL_OBJECTS,
#     211       custom_objects=custom_objects,
# --> 212       printable_module_name='layer')
#
# ~/env/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     679       else:
#     680         with CustomObjectScope(custom_objects):
# --> 681           deserialized_obj = cls.from_config(cls_config)
#     682     else:
#     683       # Then `cls` may be a function returning a class.
#
# ~/env/lib/python3.6/site-packages/keras/engine/base_layer.py in from_config(cls, config)
#     746         A layer instance.
#     747     """
# --> 748     return cls(**config)
#     749
#     750   def compute_output_shape(self, input_shape):
#
# ~/env/lib/python3.6/site-packages/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#    1162
#    1163     self.input_spec = InputSpec(min_ndim=2)
# -> 1164     self.supports_masking = True
#    1165
#    1166   def build(self, input_shape):
#
# ~/env/lib/python3.6/site-packages/keras/engine/base_layer.py in __setattr__(self, name, value)
#    2775         hasattr(self.__class__, name)):
#    2776       try:
# -> 2777         super(tf.__internal__.tracking.AutoTrackable, self).__setattr__(name, value)  # pylint: disable=bad-super-call
#    2778       except AttributeError:
#    2779         raise AttributeError(
#
# ~/env/lib/python3.6/site-packages/keras/engine/base_layer.py in supports_masking(self, value)
#    1207   @supports_masking.setter
#    1208   def supports_masking(self, value):
# -> 1209     self._supports_masking = value
#    1210
#    1211   @property
#
# ~/env/lib/python3.6/site-packages/keras/engine/base_layer.py in __setattr__(self, name, value)
#    2788
#    2789     reference_counts = self._obj_reference_counts
# -> 2790     reference_counts[value] = reference_counts.get(value, 0) + 1
#    2791
#    2792     # Clean out the old attribute, which clears _layers and _trainable_weights
#
# /usr/lib/python3.6/_collections_abc.py in get(self, key, default)
#     658         'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     659         try:
# --> 660             return self[key]
#     661         except KeyError:
#     662             return default
#
# ~/env/lib/python3.6/site-packages/keras/utils/object_identity.py in __getitem__(self, key)
#     133
#     134   def __getitem__(self, key):
# --> 135     return self._storage[self._wrap_key(key)]
#     136
#     137   def __setitem__(self, key, value):
#
# ~/env/lib/python3.6/site-packages/keras/utils/object_identity.py in _wrap_key(self, key)
#     130
#     131   def _wrap_key(self, key):
# --> 132     return _ObjectIdentityWrapper(key)
#     133
#     134   def __getitem__(self, key):
#
# KeyboardInterrupt:

# %%
seg2csv(saved, 'myseg.csv') # Save CNN outputs into a csv file for comparison with ground truth later on

# %% [markdown]
# # The following code cells are from initial repo, and they can be ignored

# %%
# select a media to analyse
# any media supported by ffmpeg may be used (video, audio, urls)
media = './media/musanmix.mp3'

# %%
# create an instance of speech segmenter
# this loads neural networks and may last few seconds
# Warnings have no incidence on the results
seg = Segmenter()

# %%
# segmentation is performed using the __call__ method of the segmenter instance
segmentation = seg(media)
# Out:
# /home/ddoukhan/gitrepos/inaSpeechSegmenter/env2/lib/python3.8/site-packages/pyannote.algorithms-0.8-py3.8.egg/pyannote/algorithms/utils/viterbi.py:86: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(
# /home/ddoukhan/gitrepos/inaSpeechSegmenter/env2/lib/python3.8/site-packages/pyannote.algorithms-0.8-py3.8.egg/pyannote/algorithms/utils/viterbi.py:95: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return np.vstack(

# %%
# the result is a list of tuples
# each tuple contains:
# * label in 'male', 'female', 'music', 'noEnergy'
# * start time of the segment
# * end time of the segment
print(segmentation)
# Out:
# [('music', 0.0, 22.48), ('noEnergy', 22.48, 29.080000000000002), ('noise', 29.080000000000002, 52.800000000000004), ('noEnergy', 52.800000000000004, 54.78), ('noise', 54.78, 55.74), ('noEnergy', 55.74, 63.34), ('male', 63.34, 68.26), ('noEnergy', 68.26, 68.92), ('male', 68.92, 71.60000000000001), ('noEnergy', 71.60000000000001, 72.0), ('male', 72.0, 73.82000000000001), ('noEnergy', 73.82000000000001, 74.5)]

# %%
# this writes the resulting segmentation into a csvfile
# the csv file may be used to import segmentation into visualization softwares,
# such as sonic-visualiser: https://www.sonicvisualiser.org
seg2csv(segmentation, 'myseg.csv')

# %%
# Here is the resulting CSV
# !cat myseg.csv
# Out:
# id	label
# id10286	female
# id10286	female

# %%
# export to praat TextGrid is also supported
seg2textgrid(segmentation, 'myseg.TextGrid')

# %%
# !cat myseg.TextGrid
# Out:
# File type = "ooTextFile"
# Object class = "TextGrid"
#
# xmin = 0.000000
# xmax = 74.500000
# tiers? <exists>
# size = 1
# item []:
# 	item [1]:
# 		class = "IntervalTier"
# 		name = "inaSpeechSegmenter"
# 		xmin = 0.000000
# 		xmax = 74.500000
# 		intervals: size = 12
# 		intervals[1]:
# 			 xmin = 0.000000
# 			 xmax = 22.480000
# 			 text = "music"
# 		intervals[2]:
# 			 xmin = 22.480000
# 			 xmax = 29.080000
# 			 text = "noEnergy"
# 		intervals[3]:
# 			 xmin = 29.080000
# 			 xmax = 52.800000
# 			 text = "noise"
# 		intervals[4]:
# 			 xmin = 52.800000
# 			 xmax = 54.780000
# 			 text = "noEnergy"
# 		intervals[5]:
# 			 xmin = 54.780000
# 			 xmax = 55.740000
# 			 text = "noise"
# 		intervals[6]:
# 			 xmin = 55.740000
# 			 xmax = 63.340000
# 			 text = "noEnergy"
# 		intervals[7]:
# 			 xmin = 63.340000
# 			 xmax = 68.260000
# 			 text = "male"
# 		intervals[8]:
# 			 xmin = 68.260000
# 			 xmax = 68.920000
# 			 text = "noEnergy"
# 		intervals[9]:
# 			 xmin = 68.920000
# 			 xmax = 71.600000
# 			 text = "male"
# 		intervals[10]:
# 			 xmin = 71.600000
# 			 xmax = 72.000000
# 			 text = "noEnergy"
# 		intervals[11]:
# 			 xmin = 72.000000
# 			 xmax = 73.820000
# 			 text = "male"
# 		intervals[12]:
# 			 xmin = 73.820000
# 			 xmax = 74.500000
# 			 text = "noEnergy"
